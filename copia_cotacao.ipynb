# %% [markdown]
# Pequeno projeto de puxar bases de dados financeiros direto com o Python. Próximos passos serão colocar-los em um índice de base 100 e plotar todos juntos, para ver o que mais subiu, mais desceu, etc.

# %%
import pandas as pd
import pandas_datareader.data as pdr
import yfinance
import matplotlib.pyplot as plt

# %%
yfinance.pdr_override() # por conta dos erros que estavam dando no arquivo anterior existe esse método de ajuste

# %%
ativos = ['ITUB3.SA', 'VALE3.SA', 'PETR3.SA', '^BVSP']

# %%
data_inicial = '2023-01-01'
data_final = '2023-06-30'

tabela_cotacoes = pdr.get_data_yahoo('ITUB3.SA', data_inicial, data_final)['Adj Close']

display(tabela_cotacoes)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# Date
# 2023-01-02    20.556984
# 2023-01-03    20.164055
# 2023-01-04    20.183216
# 2023-01-05    20.777409
# 2023-01-06    21.045753
#                 ...
# 2023-06-23    24.356390
# 2023-06-26    24.287394
# 2023-06-27    24.119827
# 2023-06-28    23.942404
# 2023-06-29    24.129683
# Name: Adj Close, Length: 123, dtype: float64

# %%
tabela_cotacoes.plot()
plt.show()
